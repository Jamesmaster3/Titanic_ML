# %%
import pandas as pd
import numpy as np

test = pd.read_csv('test.csv', index_col=0)
train = pd.read_csv('train.csv', index_col=0)


train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# preprocessing
train = train.drop(['Name', 'Sex', 'Cabin'], axis=1)
# Out:
# (891,)
#              Pclass   Age  SibSp  Parch     Fare
# PassengerId
# 1                 3  22.0      1      0   7.2500
# 2                 1  38.0      1      0  71.2833
# 3                 3  26.0      0      0   7.9250
# 4                 1  35.0      1      0  53.1000
# 5                 3  35.0      0      0   8.0500

# %%
# selecting X and y
y = train['Survived']
print(y.shape)
X = train.drop('Survived', axis=1)
X.head()

# %%
# splitting training data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

print(X_train.shape) # more test data is better model
print(X_test.shape)
# Out:
# (534, 5)
# (357, 5)

# %%
# also try out decision tree model 
from sklearn.tree import DecisionTreeClassifier
dct = DecisionTreeClassifier()
dct.fit(X_train, y_train)

# Accuracy of our model based on our test output and prediction output
y_pred_dct = dct.predict(X_test)
print('Accuracy DecisionTree:', metrics.accuracy_score(y_test, y_pred_dct))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 4
#       2 from sklearn.tree import DecisionTreeClassifier
#       3 dct = DecisionTreeClassifier()
# ----> 4 dct.fit(X_train, y_train)
#       6 # Accuracy of our model based on our test output and prediction output
#       7 y_pred_dct = dct.predict(X_test)
#
# File c:\Users\jimbe\OneDrive\Office\Python\Kaggle\Titanic_ML\venv\lib\site-packages\sklearn\tree\_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
# ...
